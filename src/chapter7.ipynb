# %% [markdown]
# Keras로 MF 구현하기

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import Model
from keras.layers import Input, Embedding, Dot, Add, Flatten
from keras.regularizers import l2
from keras.optimizers import SGD, Adamax
from chapter7_modules import get_dataset_2, RMSE
import multiprocessing as mp
import pandas as pd
import numpy as np

n_CPU = mp.cpu_count()

_, _, ratings = get_dataset_2()

K = 200
M = ratings.user_id.max() + 1
N = ratings.movie_id.max() + 1

user = Input(shape=(1, ))
item = Input(shape=(1, ))
P_embedding = Embedding(M, K, embeddings_regularizer=l2())(user)
Q_embedding = Embedding(N, K, embeddings_regularizer=l2())(item)
user_bias = Embedding(M, 1, embeddings_regularizer=l2())(user)
item_bias = Embedding(N, 1, embeddings_regularizer=l2())(item)
R = Dot(axes=2)([P_embedding, Q_embedding])
R = Add()([R, user_bias])
R = Flatten()(R)

model = Model(inputs=[user, item], outputs=R)
model.compile(
  loss=RMSE,
  optimizer=SGD(),
  metrics=[RMSE]
)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1)]          0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  embedding (Embedding)          (None, 1, 200)       188800      ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, 1, 200)       336600      ['input_2[0][0]']
#
#  dot (Dot)                      (None, 1, 1)         0           ['embedding[0][0]',
#                                                                   'embedding_1[0][0]']
#
#  embedding_2 (Embedding)        (None, 1, 1)         944         ['input_1[0][0]']
#
#  add (Add)                      (None, 1, 1)         0           ['dot[0][0]',
#                                                                   'embedding_2[0][0]']
#
#  flatten (Flatten)              (None, 1)            0           ['add[0][0]']
#
# ==================================================================================================
# Total params: 526,344
# Trainable params: 526,344
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(ratings[['user_id', 'movie_id']], ratings['rating'], train_size=0.8, random_state=10)

# %%
y_train.mean()
# Out:
# 3.528825

# %%
fit_kwargs = {
  'x':[X_train.user_id.values, X_train.movie_id.values],
  'y':y_train.values - y_train.mean(),
  'epochs':60,
  'batch_size':256,
  'validation_data': (
    [X_test.user_id.values, X_test.movie_id.values],
    y_test.values - y_test.mean()
  ),
  'workers':n_CPU
}

result = model.fit(**fit_kwargs)
# Out:
# Epoch 1/60
# 313/313 [==============================] - 2s 3ms/step - loss: 5.2553 - RMSE: 1.1257 - val_loss: 4.9993 - val_RMSE: 1.1236
# Epoch 2/60
# 313/313 [==============================] - 1s 3ms/step - loss: 4.7680 - RMSE: 1.1245 - val_loss: 4.5420 - val_RMSE: 1.1224
# Epoch 3/60
# 313/313 [==============================] - 1s 3ms/step - loss: 4.3380 - RMSE: 1.1230 - val_loss: 4.1386 - val_RMSE: 1.1213
# Epoch 4/60
# 313/313 [==============================] - 1s 3ms/step - loss: 3.9586 - RMSE: 1.1222 - val_loss: 3.7826 - val_RMSE: 1.1202
# Epoch 5/60
# 313/313 [==============================] - 1s 3ms/step - loss: 3.6240 - RMSE: 1.1211 - val_loss: 3.4686 - val_RMSE: 1.1193
# Epoch 6/60
# 313/313 [==============================] - 1s 3ms/step - loss: 3.3286 - RMSE: 1.1201 - val_loss: 3.1916 - val_RMSE: 1.1184
# Epoch 7/60
# 313/313 [==============================] - 1s 3ms/step - loss: 3.0681 - RMSE: 1.1192 - val_loss: 2.9472 - val_RMSE: 1.1176
# Epoch 8/60
# 313/313 [==============================] - 1s 3ms/step - loss: 2.8381 - RMSE: 1.1182 - val_loss: 2.7315 - val_RMSE: 1.1169
# Epoch 9/60
# 313/313 [==============================] - 1s 3ms/step - loss: 2.6355 - RMSE: 1.1177 - val_loss: 2.5413 - val_RMSE: 1.1162
# Epoch 10/60
# 313/313 [==============================] - 1s 3ms/step - loss: 2.4566 - RMSE: 1.1168 - val_loss: 2.3735 - val_RMSE: 1.1156
# Epoch 11/60
# 313/313 [==============================] - 1s 3ms/step - loss: 2.2988 - RMSE: 1.1164 - val_loss: 2.2254 - val_RMSE: 1.1150
# Epoch 12/60
# 313/313 [==============================] - 1s 3ms/step - loss: 2.1596 - RMSE: 1.1158 - val_loss: 2.0947 - val_RMSE: 1.1145
# Epoch 13/60
# 313/313 [==============================] - 1s 3ms/step - loss: 2.0366 - RMSE: 1.1150 - val_loss: 1.9795 - val_RMSE: 1.1140
# Epoch 14/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.9283 - RMSE: 1.1147 - val_loss: 1.8778 - val_RMSE: 1.1135
# Epoch 15/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.8326 - RMSE: 1.1141 - val_loss: 1.7881 - val_RMSE: 1.1131
# Epoch 16/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.7483 - RMSE: 1.1139 - val_loss: 1.7089 - val_RMSE: 1.1127
# Epoch 17/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.6738 - RMSE: 1.1132 - val_loss: 1.6391 - val_RMSE: 1.1123
# Epoch 18/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.6082 - RMSE: 1.1130 - val_loss: 1.5775 - val_RMSE: 1.1120
# Epoch 19/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.5502 - RMSE: 1.1124 - val_loss: 1.5231 - val_RMSE: 1.1117
# Epoch 20/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4990 - RMSE: 1.1123 - val_loss: 1.4752 - val_RMSE: 1.1114
# Epoch 21/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4540 - RMSE: 1.1120 - val_loss: 1.4329 - val_RMSE: 1.1111
# Epoch 22/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4141 - RMSE: 1.1117 - val_loss: 1.3955 - val_RMSE: 1.1109
# Epoch 23/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.3790 - RMSE: 1.1114 - val_loss: 1.3626 - val_RMSE: 1.1106
# Epoch 24/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.3480 - RMSE: 1.1112 - val_loss: 1.3335 - val_RMSE: 1.1104
# Epoch 25/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.3208 - RMSE: 1.1112 - val_loss: 1.3079 - val_RMSE: 1.1102
# Epoch 26/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.2967 - RMSE: 1.1108 - val_loss: 1.2853 - val_RMSE: 1.1100
# Epoch 27/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.2753 - RMSE: 1.1106 - val_loss: 1.2653 - val_RMSE: 1.1099
# Epoch 28/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.2567 - RMSE: 1.1106 - val_loss: 1.2477 - val_RMSE: 1.1097
# Epoch 29/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.2401 - RMSE: 1.1101 - val_loss: 1.2322 - val_RMSE: 1.1096
# Epoch 30/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.2255 - RMSE: 1.1101 - val_loss: 1.2185 - val_RMSE: 1.1094
# Epoch 31/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.2126 - RMSE: 1.1099 - val_loss: 1.2064 - val_RMSE: 1.1093
# Epoch 32/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.2012 - RMSE: 1.1099 - val_loss: 1.1958 - val_RMSE: 1.1092
# Epoch 33/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1912 - RMSE: 1.1097 - val_loss: 1.1863 - val_RMSE: 1.1091
# Epoch 34/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1823 - RMSE: 1.1095 - val_loss: 1.1780 - val_RMSE: 1.1090
# Epoch 35/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1744 - RMSE: 1.1096 - val_loss: 1.1707 - val_RMSE: 1.1089
# Epoch 36/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1676 - RMSE: 1.1093 - val_loss: 1.1643 - val_RMSE: 1.1088
# Epoch 37/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1614 - RMSE: 1.1091 - val_loss: 1.1586 - val_RMSE: 1.1087
# Epoch 38/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1562 - RMSE: 1.1092 - val_loss: 1.1535 - val_RMSE: 1.1086
# Epoch 39/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1514 - RMSE: 1.1090 - val_loss: 1.1491 - val_RMSE: 1.1085
# Epoch 40/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1472 - RMSE: 1.1089 - val_loss: 1.1452 - val_RMSE: 1.1085
# Epoch 41/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1435 - RMSE: 1.1090 - val_loss: 1.1417 - val_RMSE: 1.1084
# Epoch 42/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1403 - RMSE: 1.1091 - val_loss: 1.1387 - val_RMSE: 1.1084
# Epoch 43/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1374 - RMSE: 1.1089 - val_loss: 1.1360 - val_RMSE: 1.1083
# Epoch 44/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1348 - RMSE: 1.1087 - val_loss: 1.1336 - val_RMSE: 1.1083
# Epoch 45/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1326 - RMSE: 1.1085 - val_loss: 1.1315 - val_RMSE: 1.1082
# Epoch 46/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1306 - RMSE: 1.1085 - val_loss: 1.1297 - val_RMSE: 1.1082
# Epoch 47/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1289 - RMSE: 1.1086 - val_loss: 1.1281 - val_RMSE: 1.1081
# Epoch 48/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1275 - RMSE: 1.1085 - val_loss: 1.1266 - val_RMSE: 1.1081
# Epoch 49/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1261 - RMSE: 1.1087 - val_loss: 1.1254 - val_RMSE: 1.1081
# Epoch 50/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1248 - RMSE: 1.1085 - val_loss: 1.1242 - val_RMSE: 1.1080
# Epoch 51/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1238 - RMSE: 1.1085 - val_loss: 1.1233 - val_RMSE: 1.1080
# Epoch 52/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1230 - RMSE: 1.1085 - val_loss: 1.1224 - val_RMSE: 1.1080
# Epoch 53/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1221 - RMSE: 1.1085 - val_loss: 1.1216 - val_RMSE: 1.1079
# Epoch 54/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1213 - RMSE: 1.1083 - val_loss: 1.1209 - val_RMSE: 1.1079
# Epoch 55/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1208 - RMSE: 1.1086 - val_loss: 1.1203 - val_RMSE: 1.1079
# Epoch 56/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1201 - RMSE: 1.1083 - val_loss: 1.1198 - val_RMSE: 1.1079
# Epoch 57/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1197 - RMSE: 1.1084 - val_loss: 1.1193 - val_RMSE: 1.1079
# Epoch 58/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1192 - RMSE: 1.1084 - val_loss: 1.1189 - val_RMSE: 1.1078
# Epoch 59/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1187 - RMSE: 1.1081 - val_loss: 1.1186 - val_RMSE: 1.1078
# Epoch 60/60
# 313/313 [==============================] - 1s 3ms/step - loss: 1.1184 - RMSE: 1.1084 - val_loss: 1.1183 - val_RMSE: 1.1078

# %%
import matplotlib.pyplot as plt

plt.plot(result.history['RMSE'], label='Train RMSE')
plt.plot(result.history['val_RMSE'], label='Test RMSE')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
user_ids = X_test.user_id.values[:6]
movie_ids = X_test.movie_id.values[:6]

predictions = model.predict([user_ids, movie_ids]) + y_train.mean()

result_df = pd.DataFrame()
result_df['Actuals'] = y_test.values[:6]  
result_df['Predictions'] = predictions 

result_df
# Out:
# 1/1 [==============================] - 0s 89ms/step
#    Actuals  Predictions
# 0        4     3.488547
# 1        1     3.530004
# 2        4     3.535635
# 3        3     3.539645
# 4        1     3.537844
# 5        4     3.521601

# %%
from chapter7_modules import RMSE2

user_ids = X_test.user_id.values
movie_ids = X_test.movie_id.values

y_pred = model.predict([user_ids, movie_ids])
y_pred = np.ravel(y_pred, order='C') + y_train.mean()# 2 dim -> 1 dim 
y_true = y_test.values 

RMSE2(y_true, y_pred)
# Out:
# 625/625 [==============================] - 1s 1ms/step
# 1.1090381514744196

# %% [markdown]
# 은닉층 추가

# %%
from sklearn.model_selection import train_test_split

_, _, ratings = get_dataset_2()


X_train, X_test, y_train, y_test = train_test_split(
  ratings[['user_id', 'movie_id']], 
  ratings['rating'], train_size=0.8, 
  random_state=10
)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import Model
from keras.layers import Input, Embedding, Dot, Add, Flatten, Dense, Concatenate, Activation
from keras.regularizers import l2
from keras.optimizers import SGD, Adamax
from chapter7_modules import get_dataset_2, RMSE
import multiprocessing as mp
import pandas as pd
import numpy as np

n_CPU = mp.cpu_count()

_, _, ratings = get_dataset_2()

K = 200
M = ratings.user_id.max() + 1
N = ratings.movie_id.max() + 1

user = Input(shape=(1, ))
item = Input(shape=(1, ))

P_embedding = Embedding(M, K, embeddings_regularizer=l2())(user)
Q_embedding = Embedding(N, K, embeddings_regularizer=l2())(item)
user_bias = Embedding(M, 1, embeddings_regularizer=l2())(user)
item_bias = Embedding(N, 1, embeddings_regularizer=l2())(item)

# Concatenate layers , 단순히 합치는게 어떤 의미가 있는거지?
P_embedding_flatten = Flatten()(P_embedding)
Q_embedding_flatten = Flatten()(Q_embedding)
user_bias_flatten = Flatten()(user_bias)
item_bias_flatten = Flatten()(item_bias)
R = Concatenate()([P_embedding_flatten, Q_embedding_flatten, user_bias_flatten, item_bias_flatten])

R = Dense(2048)(R)
R = Activation('relu')(R)

R = Dense(256)(R)
R = Activation('linear')(R)
R = Dense(1)(R)

model = Model(inputs=[user, item], outputs=R)
model.compile(
  loss=RMSE,
  optimizer=SGD(),
  metrics=[RMSE]
)
model.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_28 (InputLayer)          [(None, 1)]          0           []
#
#  input_29 (InputLayer)          [(None, 1)]          0           []
#
#  embedding_53 (Embedding)       (None, 1, 200)       188800      ['input_28[0][0]']
#
#  embedding_54 (Embedding)       (None, 1, 200)       336600      ['input_29[0][0]']
#
#  embedding_55 (Embedding)       (None, 1, 1)         944         ['input_28[0][0]']
#
#  embedding_56 (Embedding)       (None, 1, 1)         1683        ['input_29[0][0]']
#
#  flatten_41 (Flatten)           (None, 200)          0           ['embedding_53[0][0]']
#
#  flatten_42 (Flatten)           (None, 200)          0           ['embedding_54[0][0]']
#
#  flatten_43 (Flatten)           (None, 1)            0           ['embedding_55[0][0]']
#
#  flatten_44 (Flatten)           (None, 1)            0           ['embedding_56[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 402)          0           ['flatten_41[0][0]',
#                                                                   'flatten_42[0][0]',
#                                                                   'flatten_43[0][0]',
#                                                                   'flatten_44[0][0]']
#
#  dense_36 (Dense)               (None, 2048)         825344      ['concatenate_12[0][0]']
#
#  activation_24 (Activation)     (None, 2048)         0           ['dense_36[0][0]']
#
#  dense_37 (Dense)               (None, 256)          524544      ['activation_24[0][0]']
#
#  activation_25 (Activation)     (None, 256)          0           ['dense_37[0][0]']
#
#  dense_38 (Dense)               (None, 1)            257         ['activation_25[0][0]']
#
# ==================================================================================================
# Total params: 1,878,172
# Trainable params: 1,878,172
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
fit_kwargs = {
  'x':[X_train.user_id.values, X_train.movie_id.values],
  'y':y_train.values - y_train.mean(),
  'epochs':65,
  'batch_size':512,
  'validation_data': (
    [X_test.user_id.values, X_test.movie_id.values],
    y_test.values - y_train.mean()
  ),
  'workers':n_CPU
}

result = model.fit(**fit_kwargs)
# Out:
# Epoch 1/65
# 157/157 [==============================] - 4s 23ms/step - loss: 5.3833 - RMSE: 1.1256 - val_loss: 5.2477 - val_RMSE: 1.1223
# Epoch 2/65
# 157/157 [==============================] - 4s 22ms/step - loss: 5.1232 - RMSE: 1.1243 - val_loss: 4.9957 - val_RMSE: 1.1213
# Epoch 3/65
# 157/157 [==============================] - 4s 26ms/step - loss: 4.8789 - RMSE: 1.1231 - val_loss: 4.7594 - val_RMSE: 1.1208
# Epoch 4/65
# 157/157 [==============================] - 4s 24ms/step - loss: 4.6495 - RMSE: 1.1227 - val_loss: 4.5370 - val_RMSE: 1.1197
# Epoch 5/65
# 157/157 [==============================] - 4s 26ms/step - loss: 4.4340 - RMSE: 1.1214 - val_loss: 4.3283 - val_RMSE: 1.1189
# Epoch 6/65
# 157/157 [==============================] - 4s 24ms/step - loss: 4.2316 - RMSE: 1.1208 - val_loss: 4.1323 - val_RMSE: 1.1181
# Epoch 7/65
# 157/157 [==============================] - 4s 24ms/step - loss: 4.0415 - RMSE: 1.1195 - val_loss: 3.9482 - val_RMSE: 1.1173
# Epoch 8/65
# 157/157 [==============================] - 4s 23ms/step - loss: 3.8627 - RMSE: 1.1192 - val_loss: 3.7752 - val_RMSE: 1.1164
# Epoch 9/65
# 157/157 [==============================] - 4s 23ms/step - loss: 3.6949 - RMSE: 1.1181 - val_loss: 3.6126 - val_RMSE: 1.1155
# Epoch 10/65
# 157/157 [==============================] - 4s 22ms/step - loss: 3.5371 - RMSE: 1.1172 - val_loss: 3.4597 - val_RMSE: 1.1144
# Epoch 11/65
# 157/157 [==============================] - 4s 22ms/step - loss: 3.3889 - RMSE: 1.1162 - val_loss: 3.3161 - val_RMSE: 1.1133
# Epoch 12/65
# 157/157 [==============================] - 4s 23ms/step - loss: 3.2494 - RMSE: 1.1149 - val_loss: 3.1810 - val_RMSE: 1.1119
# Epoch 13/65
# 157/157 [==============================] - 4s 23ms/step - loss: 3.1182 - RMSE: 1.1131 - val_loss: 3.0539 - val_RMSE: 1.1106
# Epoch 14/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.9947 - RMSE: 1.1113 - val_loss: 2.9343 - val_RMSE: 1.1088
# Epoch 15/65
# 157/157 [==============================] - 4s 24ms/step - loss: 2.8785 - RMSE: 1.1093 - val_loss: 2.8217 - val_RMSE: 1.1070
# Epoch 16/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.7690 - RMSE: 1.1069 - val_loss: 2.7156 - val_RMSE: 1.1048
# Epoch 17/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.6657 - RMSE: 1.1044 - val_loss: 2.6155 - val_RMSE: 1.1022
# Epoch 18/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.5683 - RMSE: 1.1015 - val_loss: 2.5210 - val_RMSE: 1.0992
# Epoch 19/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.4760 - RMSE: 1.0981 - val_loss: 2.4318 - val_RMSE: 1.0960
# Epoch 20/65
# 157/157 [==============================] - 4s 24ms/step - loss: 2.3888 - RMSE: 1.0945 - val_loss: 2.3471 - val_RMSE: 1.0918
# Epoch 21/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.3059 - RMSE: 1.0896 - val_loss: 2.2668 - val_RMSE: 1.0870
# Epoch 22/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.2272 - RMSE: 1.0840 - val_loss: 2.1905 - val_RMSE: 1.0817
# Epoch 23/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.1521 - RMSE: 1.0775 - val_loss: 2.1178 - val_RMSE: 1.0753
# Epoch 24/65
# 157/157 [==============================] - 4s 24ms/step - loss: 2.0805 - RMSE: 1.0700 - val_loss: 2.0483 - val_RMSE: 1.0680
# Epoch 25/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.0118 - RMSE: 1.0606 - val_loss: 1.9820 - val_RMSE: 1.0599
# Epoch 26/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.9459 - RMSE: 1.0517 - val_loss: 1.9191 - val_RMSE: 1.0518
# Epoch 27/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.8829 - RMSE: 1.0415 - val_loss: 1.8583 - val_RMSE: 1.0420
# Epoch 28/65
# 157/157 [==============================] - 4s 26ms/step - loss: 1.8227 - RMSE: 1.0304 - val_loss: 1.8005 - val_RMSE: 1.0321
# Epoch 29/65
# 157/157 [==============================] - 5s 31ms/step - loss: 1.7652 - RMSE: 1.0198 - val_loss: 1.7462 - val_RMSE: 1.0228
# Epoch 30/65
# 157/157 [==============================] - 4s 28ms/step - loss: 1.7112 - RMSE: 1.0087 - val_loss: 1.6952 - val_RMSE: 1.0139
# Epoch 31/65
# 157/157 [==============================] - 4s 27ms/step - loss: 1.6603 - RMSE: 0.9994 - val_loss: 1.6474 - val_RMSE: 1.0058
# Epoch 32/65
# 157/157 [==============================] - 4s 27ms/step - loss: 1.6127 - RMSE: 0.9897 - val_loss: 1.6033 - val_RMSE: 0.9991
# Epoch 33/65
# 157/157 [==============================] - 4s 26ms/step - loss: 1.5683 - RMSE: 0.9813 - val_loss: 1.5614 - val_RMSE: 0.9921
# Epoch 34/65
# 157/157 [==============================] - 4s 25ms/step - loss: 1.5270 - RMSE: 0.9740 - val_loss: 1.5255 - val_RMSE: 0.9889
# Epoch 35/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.4887 - RMSE: 0.9680 - val_loss: 1.4869 - val_RMSE: 0.9818
# Epoch 36/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.4528 - RMSE: 0.9621 - val_loss: 1.4545 - val_RMSE: 0.9788
# Epoch 37/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.4194 - RMSE: 0.9572 - val_loss: 1.4227 - val_RMSE: 0.9743
# Epoch 38/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.3882 - RMSE: 0.9530 - val_loss: 1.3938 - val_RMSE: 0.9716
# Epoch 39/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.3592 - RMSE: 0.9489 - val_loss: 1.3660 - val_RMSE: 0.9682
# Epoch 40/65
# 157/157 [==============================] - 4s 25ms/step - loss: 1.3320 - RMSE: 0.9448 - val_loss: 1.3399 - val_RMSE: 0.9650
# Epoch 41/65
# 157/157 [==============================] - 4s 25ms/step - loss: 1.3068 - RMSE: 0.9421 - val_loss: 1.3162 - val_RMSE: 0.9628
# Epoch 42/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.2831 - RMSE: 0.9391 - val_loss: 1.2939 - val_RMSE: 0.9609
# Epoch 43/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.2608 - RMSE: 0.9371 - val_loss: 1.2732 - val_RMSE: 0.9590
# Epoch 44/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.2401 - RMSE: 0.9347 - val_loss: 1.2533 - val_RMSE: 0.9573
# Epoch 45/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.2207 - RMSE: 0.9328 - val_loss: 1.2349 - val_RMSE: 0.9559
# Epoch 46/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.2024 - RMSE: 0.9308 - val_loss: 1.2196 - val_RMSE: 0.9566
# Epoch 47/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.1856 - RMSE: 0.9295 - val_loss: 1.2078 - val_RMSE: 0.9600
# Epoch 48/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.1698 - RMSE: 0.9282 - val_loss: 1.1871 - val_RMSE: 0.9528
# Epoch 49/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.1549 - RMSE: 0.9266 - val_loss: 1.1742 - val_RMSE: 0.9534
# Epoch 50/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.1410 - RMSE: 0.9257 - val_loss: 1.1595 - val_RMSE: 0.9510
# Epoch 51/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.1279 - RMSE: 0.9255 - val_loss: 1.1473 - val_RMSE: 0.9505
# Epoch 52/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.1157 - RMSE: 0.9237 - val_loss: 1.1368 - val_RMSE: 0.9509
# Epoch 53/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.1043 - RMSE: 0.9231 - val_loss: 1.1276 - val_RMSE: 0.9523
# Epoch 54/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0937 - RMSE: 0.9222 - val_loss: 1.1168 - val_RMSE: 0.9508
# Epoch 55/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0837 - RMSE: 0.9220 - val_loss: 1.1104 - val_RMSE: 0.9533
# Epoch 56/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0742 - RMSE: 0.9214 - val_loss: 1.1035 - val_RMSE: 0.9550
# Epoch 57/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0655 - RMSE: 0.9211 - val_loss: 1.0889 - val_RMSE: 0.9489
# Epoch 58/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0570 - RMSE: 0.9200 - val_loss: 1.0815 - val_RMSE: 0.9489
# Epoch 59/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0491 - RMSE: 0.9199 - val_loss: 1.0748 - val_RMSE: 0.9495
# Epoch 60/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0422 - RMSE: 0.9199 - val_loss: 1.0669 - val_RMSE: 0.9486
# Epoch 61/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0351 - RMSE: 0.9196 - val_loss: 1.0621 - val_RMSE: 0.9505
# Epoch 62/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0288 - RMSE: 0.9193 - val_loss: 1.0557 - val_RMSE: 0.9496
# Epoch 63/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0229 - RMSE: 0.9196 - val_loss: 1.0478 - val_RMSE: 0.9476
# Epoch 64/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0170 - RMSE: 0.9188 - val_loss: 1.0422 - val_RMSE: 0.9472
# Epoch 65/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.0119 - RMSE: 0.9188 - val_loss: 1.0373 - val_RMSE: 0.9473

# %%
import matplotlib.pyplot as plt

plt.plot(result.history['RMSE'], label='Train RMSE')
plt.plot(result.history['val_RMSE'], label='Test RMSE')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %% [markdown]
# 변수에 직업 추가
# 여기에는 직업에 따라 영화 선호도가 달라질 것이라는 가정이 담겨있음

# %%
from sklearn.model_selection import train_test_split
from chapter7_modules import get_dataset_2

users, _, ratings = get_dataset_2()

occupation = {}
def convert_occ(x):
  if x in occupation:
    return occupation[x]
  else:
    occupation[x] = len(occupation)
    return occupation[x]
users['occupation'] = users['occupation'].apply(convert_occ)

ratings = pd.merge(ratings, users, on='user_id')

X_train, X_test, y_train, y_test = train_test_split(
  ratings[['user_id', 'movie_id', 'occupation']], 
  ratings['rating'], train_size=0.8, 
  random_state=10
)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import Model
from keras.layers import Input, Embedding, Dot, Add, Flatten, Dense, Concatenate, Activation
from keras.regularizers import l2
from keras.optimizers import SGD, Adamax
from chapter7_modules import get_dataset_2, RMSE
import multiprocessing as mp
import pandas as pd
import numpy as np

n_CPU = mp.cpu_count()



L = len(occupation)
  
K = 200
M = ratings.user_id.max() + 1
N = ratings.movie_id.max() + 1

user = Input(shape=(1, ))
item = Input(shape=(1, ))
occ = Input(shape=(1, ))

P_embedding = Embedding(M, K, embeddings_regularizer=l2())(user)
Q_embedding = Embedding(N, K, embeddings_regularizer=l2())(item)

occ_embedding = Embedding(L, 3, embeddings_regularizer=l2())(occ)
user_bias = Embedding(M, 1, embeddings_regularizer=l2())(user)
item_bias = Embedding(N, 1, embeddings_regularizer=l2())(item)

# Concatenate layers , 단순히 합치는게 어떤 의미가 있는거지?
P_embedding_flatten = Flatten()(P_embedding)
Q_embedding_flatten = Flatten()(Q_embedding)
user_bias_flatten = Flatten()(user_bias)
item_bias_flatten = Flatten()(item_bias)
occ_embedding_flatten = Flatten()(occ_embedding)
R = Concatenate()([P_embedding_flatten, Q_embedding_flatten, user_bias_flatten, item_bias_flatten, occ_embedding_flatten])

R = Dense(2048)(R)
R = Activation('relu')(R)

R = Dense(256)(R)
R = Activation('linear')(R)
R = Dense(1)(R)

model = Model(inputs=[user, item, occ], outputs=R)
model.compile(
  loss=RMSE,
  optimizer=SGD(),
  metrics=[RMSE]
)
model.summary()
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_33 (InputLayer)          [(None, 1)]          0           []
#
#  input_34 (InputLayer)          [(None, 1)]          0           []
#
#  input_35 (InputLayer)          [(None, 1)]          0           []
#
#  embedding_62 (Embedding)       (None, 1, 200)       188800      ['input_33[0][0]']
#
#  embedding_63 (Embedding)       (None, 1, 200)       336600      ['input_34[0][0]']
#
#  embedding_65 (Embedding)       (None, 1, 1)         944         ['input_33[0][0]']
#
#  embedding_66 (Embedding)       (None, 1, 1)         1683        ['input_34[0][0]']
#
#  embedding_64 (Embedding)       (None, 1, 3)         63          ['input_35[0][0]']
#
#  flatten_50 (Flatten)           (None, 200)          0           ['embedding_62[0][0]']
#
#  flatten_51 (Flatten)           (None, 200)          0           ['embedding_63[0][0]']
#
#  flatten_52 (Flatten)           (None, 1)            0           ['embedding_65[0][0]']
#
#  flatten_53 (Flatten)           (None, 1)            0           ['embedding_66[0][0]']
#
#  flatten_54 (Flatten)           (None, 3)            0           ['embedding_64[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 405)          0           ['flatten_50[0][0]',
#                                                                   'flatten_51[0][0]',
#                                                                   'flatten_52[0][0]',
#                                                                   'flatten_53[0][0]',
#                                                                   'flatten_54[0][0]']
#
#  dense_42 (Dense)               (None, 2048)         831488      ['concatenate_14[0][0]']
#
#  activation_28 (Activation)     (None, 2048)         0           ['dense_42[0][0]']
#
#  dense_43 (Dense)               (None, 256)          524544      ['activation_28[0][0]']
#
#  activation_29 (Activation)     (None, 256)          0           ['dense_43[0][0]']
#
#  dense_44 (Dense)               (None, 1)            257         ['activation_29[0][0]']
#
# ==================================================================================================
# Total params: 1,884,379
# Trainable params: 1,884,379
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
fit_kwargs = {
  'x':[X_train.user_id.values, X_train.movie_id.values, X_train.occupation.values],
  'y':y_train.values - y_train.mean(),
  'epochs':65,
  'batch_size':512,
  'validation_data': (
    [X_test.user_id.values, X_test.movie_id.values, X_test.occupation.values],
    y_test.values - y_train.mean()
  ),
  'workers':n_CPU
}

result = model.fit(**fit_kwargs)
# Out:
# Epoch 1/65
# 157/157 [==============================] - 4s 22ms/step - loss: 5.3972 - RMSE: 1.1249 - val_loss: 5.2647 - val_RMSE: 1.1290
# Epoch 2/65
# 157/157 [==============================] - 3s 22ms/step - loss: 5.1360 - RMSE: 1.1238 - val_loss: 5.0118 - val_RMSE: 1.1280
# Epoch 3/65
# 157/157 [==============================] - 3s 21ms/step - loss: 4.8908 - RMSE: 1.1224 - val_loss: 4.7744 - val_RMSE: 1.1271
# Epoch 4/65
# 157/157 [==============================] - 3s 22ms/step - loss: 4.6605 - RMSE: 1.1216 - val_loss: 4.5513 - val_RMSE: 1.1262
# Epoch 5/65
# 157/157 [==============================] - 4s 23ms/step - loss: 4.4441 - RMSE: 1.1208 - val_loss: 4.3418 - val_RMSE: 1.1253
# Epoch 6/65
# 157/157 [==============================] - 4s 23ms/step - loss: 4.2409 - RMSE: 1.1196 - val_loss: 4.1453 - val_RMSE: 1.1245
# Epoch 7/65
# 157/157 [==============================] - 4s 23ms/step - loss: 4.0500 - RMSE: 1.1183 - val_loss: 3.9602 - val_RMSE: 1.1234
# Epoch 8/65
# 157/157 [==============================] - 3s 22ms/step - loss: 3.8707 - RMSE: 1.1177 - val_loss: 3.7866 - val_RMSE: 1.1225
# Epoch 9/65
# 157/157 [==============================] - 4s 23ms/step - loss: 3.7022 - RMSE: 1.1162 - val_loss: 3.6232 - val_RMSE: 1.1213
# Epoch 10/65
# 157/157 [==============================] - 3s 22ms/step - loss: 3.5437 - RMSE: 1.1155 - val_loss: 3.4698 - val_RMSE: 1.1201
# Epoch 11/65
# 157/157 [==============================] - 4s 22ms/step - loss: 3.3947 - RMSE: 1.1145 - val_loss: 3.3253 - val_RMSE: 1.1187
# Epoch 12/65
# 157/157 [==============================] - 4s 22ms/step - loss: 3.2546 - RMSE: 1.1129 - val_loss: 3.1896 - val_RMSE: 1.1172
# Epoch 13/65
# 157/157 [==============================] - 4s 23ms/step - loss: 3.1228 - RMSE: 1.1110 - val_loss: 3.0619 - val_RMSE: 1.1155
# Epoch 14/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.9987 - RMSE: 1.1080 - val_loss: 2.9416 - val_RMSE: 1.1135
# Epoch 15/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.8818 - RMSE: 1.1067 - val_loss: 2.8282 - val_RMSE: 1.1112
# Epoch 16/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.7717 - RMSE: 1.1044 - val_loss: 2.7214 - val_RMSE: 1.1086
# Epoch 17/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.6678 - RMSE: 1.1009 - val_loss: 2.6206 - val_RMSE: 1.1055
# Epoch 18/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.5694 - RMSE: 1.0977 - val_loss: 2.5252 - val_RMSE: 1.1019
# Epoch 19/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.4765 - RMSE: 1.0928 - val_loss: 2.4352 - val_RMSE: 1.0979
# Epoch 20/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.3884 - RMSE: 1.0890 - val_loss: 2.3493 - val_RMSE: 1.0929
# Epoch 21/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.3046 - RMSE: 1.0835 - val_loss: 2.2681 - val_RMSE: 1.0873
# Epoch 22/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.2249 - RMSE: 1.0772 - val_loss: 2.1906 - val_RMSE: 1.0808
# Epoch 23/65
# 157/157 [==============================] - 4s 24ms/step - loss: 2.1490 - RMSE: 1.0698 - val_loss: 2.1176 - val_RMSE: 1.0739
# Epoch 24/65
# 157/157 [==============================] - 4s 24ms/step - loss: 2.0763 - RMSE: 1.0613 - val_loss: 2.0467 - val_RMSE: 1.0654
# Epoch 25/65
# 157/157 [==============================] - 4s 23ms/step - loss: 2.0069 - RMSE: 1.0530 - val_loss: 1.9793 - val_RMSE: 1.0562
# Epoch 26/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.9404 - RMSE: 1.0420 - val_loss: 1.9153 - val_RMSE: 1.0467
# Epoch 27/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.8770 - RMSE: 1.0319 - val_loss: 1.8545 - val_RMSE: 1.0370
# Epoch 28/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.8165 - RMSE: 1.0214 - val_loss: 1.7970 - val_RMSE: 1.0275
# Epoch 29/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.7595 - RMSE: 1.0106 - val_loss: 1.7430 - val_RMSE: 1.0183
# Epoch 30/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.7058 - RMSE: 1.0005 - val_loss: 1.6926 - val_RMSE: 1.0100
# Epoch 31/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.6554 - RMSE: 0.9913 - val_loss: 1.6464 - val_RMSE: 1.0032
# Epoch 32/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.6084 - RMSE: 0.9826 - val_loss: 1.6016 - val_RMSE: 0.9960
# Epoch 33/65
# 157/157 [==============================] - 4s 22ms/step - loss: 1.5646 - RMSE: 0.9752 - val_loss: 1.5611 - val_RMSE: 0.9905
# Epoch 34/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.5237 - RMSE: 0.9685 - val_loss: 1.5254 - val_RMSE: 0.9877
# Epoch 35/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.4858 - RMSE: 0.9629 - val_loss: 1.4896 - val_RMSE: 0.9831
# Epoch 36/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.4503 - RMSE: 0.9571 - val_loss: 1.4543 - val_RMSE: 0.9776
# Epoch 37/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.4173 - RMSE: 0.9539 - val_loss: 1.4233 - val_RMSE: 0.9744
# Epoch 38/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.3862 - RMSE: 0.9487 - val_loss: 1.3944 - val_RMSE: 0.9716
# Epoch 39/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.3575 - RMSE: 0.9458 - val_loss: 1.3675 - val_RMSE: 0.9692
# Epoch 40/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.3306 - RMSE: 0.9427 - val_loss: 1.3421 - val_RMSE: 0.9670
# Epoch 41/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.3051 - RMSE: 0.9397 - val_loss: 1.3193 - val_RMSE: 0.9658
# Epoch 42/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.2818 - RMSE: 0.9372 - val_loss: 1.2983 - val_RMSE: 0.9651
# Epoch 43/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.2599 - RMSE: 0.9351 - val_loss: 1.2758 - val_RMSE: 0.9625
# Epoch 44/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.2390 - RMSE: 0.9328 - val_loss: 1.2564 - val_RMSE: 0.9611
# Epoch 45/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.2199 - RMSE: 0.9309 - val_loss: 1.2376 - val_RMSE: 0.9594
# Epoch 46/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.2018 - RMSE: 0.9292 - val_loss: 1.2205 - val_RMSE: 0.9582
# Epoch 47/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.1851 - RMSE: 0.9283 - val_loss: 1.2062 - val_RMSE: 0.9585
# Epoch 48/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.1691 - RMSE: 0.9267 - val_loss: 1.1995 - val_RMSE: 0.9655
# Epoch 49/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.1544 - RMSE: 0.9261 - val_loss: 1.1751 - val_RMSE: 0.9553
# Epoch 50/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.1404 - RMSE: 0.9240 - val_loss: 1.1626 - val_RMSE: 0.9551
# Epoch 51/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.1274 - RMSE: 0.9236 - val_loss: 1.1504 - val_RMSE: 0.9545
# Epoch 52/65
# 157/157 [==============================] - 4s 23ms/step - loss: 1.1153 - RMSE: 0.9227 - val_loss: 1.1418 - val_RMSE: 0.9568
# Epoch 53/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.1038 - RMSE: 0.9227 - val_loss: 1.1270 - val_RMSE: 0.9531
# Epoch 54/65
# 157/157 [==============================] - 4s 25ms/step - loss: 1.0934 - RMSE: 0.9219 - val_loss: 1.1177 - val_RMSE: 0.9539
# Epoch 55/65
# 157/157 [==============================] - 4s 25ms/step - loss: 1.0830 - RMSE: 0.9210 - val_loss: 1.1088 - val_RMSE: 0.9536
# Epoch 56/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.0736 - RMSE: 0.9211 - val_loss: 1.0985 - val_RMSE: 0.9522
# Epoch 57/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.0650 - RMSE: 0.9203 - val_loss: 1.0951 - val_RMSE: 0.9575
# Epoch 58/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.0567 - RMSE: 0.9197 - val_loss: 1.0833 - val_RMSE: 0.9526
# Epoch 59/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.0488 - RMSE: 0.9195 - val_loss: 1.0751 - val_RMSE: 0.9518
# Epoch 60/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.0417 - RMSE: 0.9197 - val_loss: 1.0699 - val_RMSE: 0.9538
# Epoch 61/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.0349 - RMSE: 0.9192 - val_loss: 1.0617 - val_RMSE: 0.9519
# Epoch 62/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.0284 - RMSE: 0.9192 - val_loss: 1.0565 - val_RMSE: 0.9527
# Epoch 63/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.0225 - RMSE: 0.9197 - val_loss: 1.0536 - val_RMSE: 0.9558
# Epoch 64/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.0166 - RMSE: 0.9183 - val_loss: 1.0447 - val_RMSE: 0.9519
# Epoch 65/65
# 157/157 [==============================] - 4s 24ms/step - loss: 1.0116 - RMSE: 0.9185 - val_loss: 1.0402 - val_RMSE: 0.9523

# %%
import matplotlib.pyplot as plt

plt.plot(result.history['RMSE'], label='Train RMSE')
plt.plot(result.history['val_RMSE'], label='Test RMSE')
plt.ylabel('RMSE')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %% [markdown]
# 연습문제
# 사용자의 나이까지를 입력으로 추가한 신경망.
# 사용자 나이 데이터는 곧바로 dense layer를 통과 후 다른 layer들과 concatenate 시켜라
